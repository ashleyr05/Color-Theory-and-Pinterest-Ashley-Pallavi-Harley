# %%
from PIL import Image
import requests
from io import BytesIO
import pandas as pd

data = {"url":[], "image":[]}
my_db = pd.DataFrame(data=data)
url1 = 'https://i.pinimg.com/736x/2a/54/ea/2a54ead03e9e12f9d12ee0741fdd1dcd.jpg'
url2 = 'https://i.pinimg.com/474x/32/a0/df/32a0df5ae0b2b54d400883a2eb595a7c.jpg'
url3 = 'https://i.pinimg.com/474x/31/f3/21/31f321c3fc646e72d01e4bcafc5f64f4.jpg'
url4 = 'https://i.pinimg.com/474x/32/c6/c5/32c6c5729f87be39cdc7b84175dda237.jpg'
url5 = 'https://i.pinimg.com/474x/31/bf/83/31bf83d4b18244d2e1f5ba3c86ff8cb5.jpg'
url6 = 'https://i.pinimg.com/474x/30/38/18/303818174dc572dccc0e13d173899413.jpg'
url7 = 'https://i.pinimg.com/474x/21/54/4b/21544b3dfae477d22932fdba8b3bce54.jpg'
url8 = 'https://i.pinimg.com/474x/2d/fb/ab/2dfbab9b2ad0c424ee5ea2970504aad9.jpg'
url9 = 'https://i.pinimg.com/474x/2d/4a/7a/2d4a7a1070db587e3f1435d75c8e1d6a.jpg'
url10 = 'https://i.pinimg.com/474x/31/e0/40/31e040c3d98dc3abcb3c54c2f8f1eded.jpg'
url11 = 'https://i.pinimg.com/474x/2f/04/a0/2f04a0a422b98fcaba6b18fee5d4f392.jpg'
url12 = 'https://i.pinimg.com/474x/2f/38/1f/2f381f818641dac294333a741e21f3a0.jpg'
url13 = 'https://i.pinimg.com/474x/2c/f9/5c/2cf95cea369cbb3ff8ca5ef697b03bd8.jpg'
url14 = 'https://i.pinimg.com/474x/2d/e5/9e/2de59e9b3b7f6a7895a1ed07b0e21a43.jpg'
url15 = 'https://i.pinimg.com/474x/2f/02/c7/2f02c7071ac63242b0a73a1852b90dce.jpg'
url16 = 'https://i.pinimg.com/474x/28/62/f3/2862f366e85576fb8b7ea8929c487d6c.jpg'
url17 = 'https://i.pinimg.com/474x/2a/de/51/2ade5148bbfc310fb38642b1f07bf724.jpg'
url18 = 'https://i.pinimg.com/474x/2a/de/51/2ade5148bbfc310fb38642b1f07bf724.jpg'
url19 = 'https://i.pinimg.com/474x/2d/60/0c/2d600cbc06cac339d85ecde4173a3e68.jpg'
url20 = 'https://i.pinimg.com/474x/2b/5e/6d/2b5e6d152ddb2173bc92a5f903f423fa.jpg'
url21 = 'https://i.pinimg.com/474x/29/59/ef/2959ef743d8dd932f41616f089ad6d2d.jpg'
url22 = 'https://i.pinimg.com/474x/26/41/31/2641311251ade66832a30a6dd2ac1d58.jpg'
url23 = 'https://i.pinimg.com/474x/27/8a/01/278a0185825a74974399019208bb5c59.jpg'
url24 = 'https://i.pinimg.com/474x/27/79/e3/2779e3918c3370f6c0186f48446e0e42.jpg'
url25 = 'https://i.pinimg.com/474x/2a/74/79/2a7479374271c2cb2f3aae049c2ba8df.jpg'
url26 = 'https://i.pinimg.com/474x/29/58/b4/2958b4b89994add3bdb2031b3bed76c6.jpg'
url27 = 'https://i.pinimg.com/474x/26/20/af/2620af324b68dbf1a6e00711a9a53109.jpg'
url28 = 'https://i.pinimg.com/474x/24/d2/e3/24d2e3638fd718937756d932918aef91.jpg'
url29 = 'https://i.pinimg.com/474x/24/97/e3/2497e395ef143f1c51d46f6ed9cd92fe.jpg'
url30 = 'https://i.pinimg.com/474x/24/74/b1/2474b1c51199c32fbeafd1334d36f4e7.jpg'
url31 = 'https://i.pinimg.com/474x/24/74/b1/2474b1c51199c32fbeafd1334d36f4e7.jpg'
url32 = 'https://i.pinimg.com/474x/25/ea/94/25ea941546601369d7dc85b2c1af7c29.jpg'
url33 = 'https://i.pinimg.com/474x/22/2f/29/222f291cf61e9663cd4a4d7b35ae9795.jpg'
url34 = 'https://i.pinimg.com/474x/1f/43/b2/1f43b2f90cefd3c31abb8aceeceb9bf8.jpg'
url35 = 'https://i.pinimg.com/474x/21/44/c3/2144c32cb711aabadb5b0289f11a1345.jpg'
url36 = 'https://i.pinimg.com/474x/1d/b6/34/1db6346ee23b1bbc43474f4e92bd7201.jpg'
url37 = 'https://i.pinimg.com/474x/1f/4a/84/1f4a8453204c9beeddf1601aee5042c3.jpg'
url38 = 'https://i.pinimg.com/474x/1e/97/33/1e9733eeed731f68f5f10f8fac3d9476.jpg'
url39 = 'https://i.pinimg.com/474x/b0/93/a3/b093a3add2552a6aba987926a2e06418.jpg'
url40 = 'https://i.pinimg.com/474x/1d/4f/55/1d4f55c1a4b04d8fd7ed668007981869.jpg'
url41 = 'https://i.pinimg.com/474x/1f/4a/84/1f4a8453204c9beeddf1601aee5042c3.jpg'
url42 = 'https://i.pinimg.com/474x/1b/e7/be/1be7be32f178c579071d7c73ca1607e3.jpg'
url43 = 'https://i.pinimg.com/474x/b1/d8/d5/b1d8d505acd66383e72c8fba2e9f81ff.jpg'
url44 = 'https://i.pinimg.com/474x/4d/0c/e7/4d0ce76eb3f7de09704746c84f7765e8.jpg'
url45 = 'https://i.pinimg.com/474x/1d/1b/6e/1d1b6ee1102fe5104d8ccc91b9abc0ec.jpg'
url46 = 'https://i.pinimg.com/474x/17/60/3c/17603c7b868e1c7fa0eb09d090b93f89.jpg'
url47 = 'https://i.pinimg.com/474x/1a/6e/65/1a6e659393546acdc7f8fe3f46adc8a5.jpg'
url50 = 'https://i.pinimg.com/474x/1a/e2/78/1ae27851b24c1c72bcfb221865d95af6.jpg'
url51 = 'https://i.pinimg.com/474x/19/e9/85/19e985926f973637f9f59ec916b04b54.jpg'
url52 = 'https://i.pinimg.com/474x/19/79/be/1979be3e34ffa74a7e327569a216acb4.jpg'
url53 = 'https://i.pinimg.com/474x/17/60/3c/17603c7b868e1c7fa0eb09d090b93f89.jpg'
url54 = 'https://i.pinimg.com/474x/18/08/93/180893fa7eff42acf220e332489f3081.jpg'
url55 = 'https://i.pinimg.com/474x/19/d3/80/19d38069923707ba98c24bc87392d86a.jpg'
url56 = 'https://i.pinimg.com/474x/17/55/9c/17559cc5dcf6e45267cbdcc63f0511d0.jpg'
url57 = 'https://i.pinimg.com/474x/17/08/9a/17089a7631cbcbb92e134444e961c62c.jpg'
url58 = 'https://i.pinimg.com/474x/16/d7/42/16d742736a2ad1a1b0f8c80c84d17883.jpg'
url59 = 'https://i.pinimg.com/474x/16/03/78/1603787c100b53eb44e9d25ac0e81416.jpg'
url60 = 'https://i.pinimg.com/474x/16/11/e2/1611e2a92855e4da4c8ed014c4df4c2b.jpg'
url61 = 'https://i.pinimg.com/474x/91/7c/c9/917cc97e1b91c14e51314f56c07b8101.jpg'
url62 = 'https://i.pinimg.com/474x/15/b0/12/15b012e9a92e4948ca22ca3f2c1ede74.jpg'
url63 = 'https://i.pinimg.com/474x/16/b4/a2/16b4a2341eeb86bb64eb9c17c664764c.jpg'
url64 = 'https://i.pinimg.com/474x/15/cf/7f/15cf7f009f112051adc16057c48d1933.jpg'
url65 = 'https://i.pinimg.com/474x/15/3c/20/153c20d7f007d5847c40c7eb31b39046.jpg'
url66 = 'https://i.pinimg.com/474x/14/37/df/1437df4e7d70515267ff9889fa2eff4c.jpg'
url67 = 'https://i.pinimg.com/474x/14/0e/3d/140e3d649d47e069743b65a6d44ef374.jpg'
url68 = 'https://i.pinimg.com/474x/15/1b/65/151b651ceb88ca247b4d931c6bd743c8.jpg'
url69 = 'https://i.pinimg.com/474x/15/cd/bb/15cdbb7017789894cbd0469d4d5ea532.jpg'
url70 = 'https://i.pinimg.com/474x/86/15/73/861573f203147c177c6a3d9e88b391c2.jpg'
url71 = 'https://i.pinimg.com/474x/11/dd/86/11dd8649747f340eef3a968bebd82e24.jpg'
url72 = 'https://i.pinimg.com/474x/11/63/cd/1163cd5836d46c09e63c34c0d9d2cb43.jpg'
url73 = 'https://i.pinimg.com/474x/13/fa/c2/13fac29f1d2b22ad704a0f39c208bba2.jpg'
url74 = 'https://i.pinimg.com/474x/13/84/dd/1384dd389865cd05219df1aa480a4579.jpg'
url75 = 'https://i.pinimg.com/474x/0e/44/e1/0e44e1e9b86116438d90d65f71883534.jpg'


data = {"url": [], "image": []}
my_db = pd.DataFrame(data=data)

for i in range(1, 76):
    url_var_name = f"url{i}"
    url = globals().get(url_var_name)
    
    if url:
        try:
            response = requests.get(url)
            response.raise_for_status() 
            img = Image.open(BytesIO(response.content))

            new_data = {"url": [url], "image": [img]}
            new_df = pd.DataFrame(new_data)
            my_db = pd.concat([my_db, new_df], ignore_index=True)

        except Exception as e:
            print(f"Failed to load image from {url}: {e}")

my_db
# Out:
# /Users/pallavi/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
#                                                   url  \
# 0   https://i.pinimg.com/736x/2a/54/ea/2a54ead03e9...
# 1   https://i.pinimg.com/474x/32/a0/df/32a0df5ae0b...
# 2   https://i.pinimg.com/474x/31/f3/21/31f321c3fc6...
# 3   https://i.pinimg.com/474x/32/c6/c5/32c6c5729f8...
# 4   https://i.pinimg.com/474x/31/bf/83/31bf83d4b18...
# ..                                                ...
# 68  https://i.pinimg.com/474x/11/dd/86/11dd8649747...
# 69  https://i.pinimg.com/474x/11/63/cd/1163cd5836d...
# 70  https://i.pinimg.com/474x/13/fa/c2/13fac29f1d2...
# 71  https://i.pinimg.com/474x/13/84/dd/1384dd38986...
# 72  https://i.pinimg.com/474x/0e/44/e1/0e44e1e9b86...
#
# ...

# %%
url_list = [f"url{i}" for i in range(1, 76)]
url_list
# Out:
# ['url1',
#  'url2',
#  'url3',
#  'url4',
#  'url5',
#  'url6',
#  'url7',
#  'url8',
#  'url9',
#  'url10',
#  'url11',
#  'url12',
#  'url13',
#  'url14',
#  'url15',
#  'url16',
#  'url17',
#  'url18',
#  'url19',
#  'url20',
#  'url21',
#  'url22',
#  'url23',
#  'url24',
#  'url25',
#  'url26',
#  'url27',
#  'url28',
#  'url29',
#  'url30',
#  'url31',
#  'url32',
#  'url33',
#  'url34',
#  'url35',
#  'url36',
#  'url37',
#  'url38',
#  'url39',
#  'url40',
#  'url41',
#  'url42',
#  'url43',
#  'url44',
#  'url45',
#  'url46',
#  'url47',
#  'url48',
#  'url49',
#  'url50',
#  'url51',
#  'url52',
#  'url53',
#  'url54',
#  'url55',
#  'url56',
#  'url57',
#  'url58',
#  'url59',
#  'url60',
#  'url61',
#  'url62',
#  'url63',
#  'url64',
#  'url65',
#  'url66',
#  'url67',
#  'url68',
#  'url69',
#  'url70',
#  'url71',
#  'url72',
#  'url73',
#  'url74',
#  'url75']

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x591>

# %%
import numpy as np

all_pixels = []

Y_black_threshold = 0.1 
Y_white_threshold = 0.9 
UV_neutral_threshold = 0.05  

for index, row in my_db.iterrows():
    try:
        img = row["image"]
        img_yuv = img.convert("YCbCr")  
        yuv_data = np.array(img_yuv)   
        y = yuv_data[:, :, 0] 
        u = yuv_data[:, :, 1] 
        v = yuv_data[:, :, 2] 

        yuv_flat = np.column_stack([y.flatten(), u.flatten(), v.flatten()])

       
        is_black = yuv_flat[:, 0] < Y_black_threshold
        is_white = (yuv_flat[:, 0] > Y_white_threshold) & \
                   (np.abs(yuv_flat[:, 1]) < UV_neutral_threshold) & \
                   (np.abs(yuv_flat[:, 2]) < UV_neutral_threshold)
        valid_pixels = ~(is_black | is_white)

        all_pixels.append(yuv_flat[valid_pixels])
    except Exception as e:
        print(f"Failed to process image at {row['url']}: {e}")

if all_pixels:
    all_pixels_array = np.vstack(all_pixels)

    overall_avg_color = np.mean(all_pixels_array, axis=0)
    overall_std_dev = np.std(all_pixels_array, axis=0)

    print("Overall Average Color (YUV):", overall_avg_color)
    print("Overall Standard Deviation (YUV):", overall_std_dev)
else:
    print("No valid image data was found.")


#Use https://convertingcolors.com/yuv-color-71.2000_10.9500_14.4000.html?search=YUV(71.2,%2010.95,%2014.4) to interpret result
# Out:
# Overall Average Color (YUV): [140.22550127 117.88993366 140.30156566]
# Overall Standard Deviation (YUV): [75.63075265 11.06905386 14.51436894]

# %%
import numpy as np
import pandas as pd
from PIL import Image


Y_black_threshold = 0.1
Y_white_threshold = 0.9
UV_neutral_threshold = 0.05
resizing = (100, 100)

my_db["YUV_values"] = None

for index, row in my_db.iterrows():
    try:
        img = row["image"]
        img_resized = img.resize(resizing)
        img_yuv = img.convert("YCbCr")
        yuv_data = np.array(img_yuv)

        y = yuv_data[:, :, 0]
        u = yuv_data[:, :, 1]
        v = yuv_data[:, :, 2]

        yuv_flat = np.column_stack([y.flatten(), u.flatten(), v.flatten()])

        is_black = yuv_flat[:, 0] < Y_black_threshold
        is_white = (yuv_flat[:, 0] > Y_white_threshold) & \
                   (np.abs(yuv_flat[:, 1]) < UV_neutral_threshold) & \
                   (np.abs(yuv_flat[:, 2]) < UV_neutral_threshold)

        valid_pixels = ~(is_black | is_white)

        if valid_pixels.any():
            y_mean = yuv_flat[valid_pixels, 0].mean()
            u_mean = yuv_flat[valid_pixels, 1].mean()
            v_mean = yuv_flat[valid_pixels, 2].mean()
            yuv_value = (y_mean, u_mean, v_mean)
        else:
            yuv_value = (None, None, None)

        my_db.at[index, "YUV_values"] = yuv_value
    except Exception as e:
        print(f"Error processing image at index {index}: {e}")

print(my_db)
my_db.to_csv('warmtone.csv', index=False)
# Out:
#                                                   url  \
# 0   https://i.pinimg.com/736x/2a/54/ea/2a54ead03e9...
# 1   https://i.pinimg.com/474x/32/a0/df/32a0df5ae0b...
# 2   https://i.pinimg.com/474x/31/f3/21/31f321c3fc6...
# 3   https://i.pinimg.com/474x/32/c6/c5/32c6c5729f8...
# 4   https://i.pinimg.com/474x/31/bf/83/31bf83d4b18...
# ..                                                ...
# 68  https://i.pinimg.com/474x/11/dd/86/11dd8649747...
# 69  https://i.pinimg.com/474x/11/63/cd/1163cd5836d...
# 70  https://i.pinimg.com/474x/13/fa/c2/13fac29f1d2...
# 71  https://i.pinimg.com/474x/13/84/dd/1384dd38986...
# 72  https://i.pinimg.com/474x/0e/44/e1/0e44e1e9b86...
#
#                                                 image  \
# 0   <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1   <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 2   <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 3   <PIL.JpegImagePlugin.JpegImageFile image mode=...
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

a = []

Y_black_threshold = 0.1
Y_white_threshold = 0.9
UV_neutral_threshold = 0.05
resizing = (100, 100)

for index, row in my_db.iterrows():
    try:
        img = row["image"]
        img_resized = img.resize(resizing)
        img_yuv = img.convert("YCbCr")
        yuv_data = np.array(img_yuv)

        y = yuv_data[:, :, 0]
        u = yuv_data[:, :, 1]
        v = yuv_data[:, :, 2]

        yuv_flat = np.column_stack([y.flatten(), u.flatten(), v.flatten()])

        is_black = yuv_flat[:, 0] < Y_black_threshold
        is_white = (yuv_flat[:, 0] > Y_white_threshold) & \
                   (np.abs(yuv_flat[:, 1]) < UV_neutral_threshold) & \
                   (np.abs(yuv_flat[:, 2]) < UV_neutral_threshold)

        valid_pixels = ~(is_black | is_white)

        a.append(yuv_flat[valid_pixels])
    except Exception as e:
        print(f"")

if a:
    ar = np.vstack(a)

    yuv_palette = {}
    for i, channel in enumerate(['Y', 'U', 'V']):
        channel_data = ar[:, i]
        q1 = np.percentile(channel_data, 25)
        q2 = np.median(channel_data)
        q3 = np.percentile(channel_data, 75)
        min_val = channel_data.min()
        max_val = channel_data.max()

        iqr = q3 - q1
        lower_bound = q1 - 1.5 * iqr
        upper_bound = q3 + 1.5 * iqr
        outliers = channel_data[(channel_data < lower_bound) | (channel_data > upper_bound)]

        yuv_palette[channel] = {
            "min": min_val,
            "Q1": q1,
            "median": q2,
            "Q3": q3,
            "max": max_val,
            "outliers": outliers
        }

    for channel, stats in yuv_palette.items():
        print(f"{channel} Channel:")
        print(f"  Min: {stats['min']}")
        print(f"  Q1: {stats['Q1']}")
        print(f"  Median: {stats['median']}")
        print(f"  Q3: {stats['Q3']}")
        print(f"  Max: {stats['max']}")
        print(f"  Outliers: {stats['outliers'][:10]}...")

    plt.boxplot([ar[:, 0], ar[:, 1], ar[:, 2]],
            labels=['Y', 'U', 'V'], 
            patch_artist=True,
            medianprops=dict(color='white', linewidth=2))
    plt.title("YUV Color Distribution-- Warm Tone")
    plt.ylabel("Normalized Value")
    plt.grid(True)
    plt.show()

else:
    print("No valid image data was found.")
# Out:
# Y Channel:
#   Min: 1
#   Q1: 76.0
#   Median: 140.0
#   Q3: 206.0
#   Max: 255
#   Outliers: []...
# U Channel:
#   Min: 16
#   Q1: 110.0
#   Median: 120.0
#   Q3: 128.0
#   Max: 208
#   Outliers: [75 79 80 80 80 80 80 80 80 80]...
# V Channel:
#   Min: 30
#   Q1: 128.0
#   Median: 137.0
#   Q3: 152.0
#   Max: 253
#   Outliers: [87 76 76 76 76 76 76 76 76 76]...
# /var/folders/_m/8n2245qs5kl8kpy43gd_y7tm0000gp/T/ipykernel_51171/996613406.py:70: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([ar[:, 0], ar[:, 1], ar[:, 2]],

# %%
plt.hist(y.flatten(), bins=256, range=(-128, 127), color='green', alpha=0.6, label='Y Channel- Brightness')
plt.hist(u.flatten(), bins=256, range=(-128, 127), color='blue', alpha=0.6, label='U Channel- Blue Luminance')
plt.hist(v.flatten(), bins=256, range=(-128, 127), color='red', alpha=0.6, label='V Channel- Red Luminance')
plt.legend()
plt.show()
