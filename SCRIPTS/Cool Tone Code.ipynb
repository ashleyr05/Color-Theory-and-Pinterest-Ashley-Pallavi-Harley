# %%
from PIL import Image
import requests
from io import BytesIO
import pandas as pd

data = {"url":[], "image":[]}
my_db = pd.DataFrame(data=data)
url1 = 'https://i.pinimg.com/474x/3b/1c/ec/3b1cec8e035c0ccc6a38c8f6325b59c3.jpg'
url2 = 'https://i.pinimg.com/474x/3a/04/15/3a0415feca8e191215539ea1b70256c6.jpg'
url3 = 'https://i.pinimg.com/474x/38/74/95/387495d3b7e5580b3317f910594ff7e9.jpg'
url4 = 'https://i.pinimg.com/474x/38/6d/77/386d77debb7134e1a8625f752d3cdfd5.jpg'
url5 = 'https://i.pinimg.com/474x/34/54/ff/3454ff98c633a5c417ebe9915fdf9689.jpg'
url6 = 'https://i.pinimg.com/474x/34/22/27/3422277dbf5a43fd117a32cdfc6fd0ce.jpg'
url7 = 'https://i.pinimg.com/474x/34/85/4c/34854c3f1eeecdda8c5f02560d0ed28c.jpg'
url8 = 'https://i.pinimg.com/474x/34/c4/4d/34c44de9f61700ae5d1c075c69f8dc54.jpg'
url9 = 'https://i.pinimg.com/474x/31/4a/39/314a3958a03fd464fdb38a33cd5cfa7e.jpg'
url10 = 'https://i.pinimg.com/474x/33/ae/46/33ae46de1fb0b222480a6785834dc941.jpg'
url11 = 'https://i.pinimg.com/474x/31/94/1b/31941bcb3ef1be9727ecd165e63d7e98.jpg'
url12 = 'https://i.pinimg.com/474x/32/69/3b/32693be9fafe9b9fa690318e507955c0.jpg'
url13 = 'https://i.pinimg.com/474x/31/1e/36/311e36d686f17ea02c76f5db5f628c14.jpg'
url14 = 'https://i.pinimg.com/474x/30/ba/2a/30ba2a2a4d32d1b650789c981e441da0.jpg'
url15 = 'https://i.pinimg.com/474x/2f/06/0f/2f060fb4451b588daed84a15bdac7d1e.jpg'
url16 = 'https://i.pinimg.com/474x/2f/7d/a9/2f7da9893a871afbc1f91e2e726f2ecb.jpg'
url17 = 'https://i.pinimg.com/474x/2d/8f/b7/2d8fb70050b74a3c75ab4c43b683431d.jpg'
url18 = 'https://i.pinimg.com/474x/2d/56/92/2d56920607eac8ee17c8e026835cfa10.jpg'
url19 = 'https://i.pinimg.com/474x/2f/06/0f/2f060fb4451b588daed84a15bdac7d1e.jpg'
url20 = 'https://i.pinimg.com/474x/2e/b9/e6/2eb9e63ff774727ac8a478861a1a7c27.jpg'
url21 = 'https://i.pinimg.com/474x/2a/8a/79/2a8a7955e0bca7a17e1e427f1d311c02.jpg'
url22 = 'https://i.pinimg.com/474x/2b/57/40/2b57402e2714cbcd15360c2d0e364ef2.jpg'
url23 = 'https://i.pinimg.com/474x/2b/c2/bf/2bc2bff8565e84fd4a81f82f6f622700.jpg'
url24 = 'https://i.pinimg.com/474x/2c/1a/8f/2c1a8ff8738cf08634d2fd8096efff8f.jpg'
url25 = 'https://i.pinimg.com/474x/27/41/ba/2741ba0404a391fba4062fb288d2d070.jpg'
url26 = 'https://i.pinimg.com/474x/29/2a/3b/292a3b8945e577f0bed4d9dd8da1afc4.jpg'
url27 = 'https://i.pinimg.com/474x/29/2a/3b/292a3b8945e577f0bed4d9dd8da1afc4.jpg'
url28 = 'https://i.pinimg.com/474x/28/6e/28/286e285f45063d1a1b1b825a7944e7e6.jpg'
url29 = 'https://i.pinimg.com/474x/29/04/fd/2904fd7d56ca0d35d964c7aa48177dd0.jpg'
url30 = 'https://i.pinimg.com/474x/93/3f/1f/933f1f7b324b59d882d82b9422c54a9d.jpg'
url31 = 'https://i.pinimg.com/474x/25/7b/8b/257b8bd03830a965fe8762f7d2dcd328.jpg'
url32 = 'https://i.pinimg.com/474x/26/6c/5e/266c5e08cd3349a0d83481eb0733ecc0.jpg'
url33 = 'https://i.pinimg.com/474x/22/97/d7/2297d7620de60ad0127ee11df54f0d50.jpg'
url34 = 'https://i.pinimg.com/474x/22/c5/ab/22c5ab6059d872cde927c8cfa8ae2a9d.jpg'
url35 = 'https://i.pinimg.com/474x/25/30/69/2530694ed109e47fb80b87186dc9da8c.jpg'
url36 = 'https://i.pinimg.com/474x/1f/f2/f4/1ff2f40239c5863cb63aa03c277e1918.jpg'
url37 = 'https://i.pinimg.com/474x/20/f1/08/20f1086a3480caf9970e4d2cdd740bb9.jpg'
url38 = 'https://i.pinimg.com/474x/24/4d/a7/244da7ed41f5d7175155c7cfcce3ce62.jpg'
url39 = 'https://i.pinimg.com/474x/1f/31/a0/1f31a05165780599a04721cb7dd33d9f.jpg'
url40 = 'https://i.pinimg.com/474x/1e/e4/2d/1ee42d85eaa8d77ceef8220b938ea521.jpg'
url41 = 'https://i.pinimg.com/474x/1f/07/ad/1f07ad6fa82b49628bdbd930148f4f2f.jpg'
url42 = 'https://i.pinimg.com/474x/1f/c4/90/1fc490565bcd002614f47d3ed27d01a9.jpg'
url43 = 'https://i.pinimg.com/474x/1c/82/65/1c82652d7cbd1415ec22ae487f93e95a.jpg'
url44 = 'https://i.pinimg.com/474x/1d/92/63/1d92635c20087926daf428d884b181f8.jpg'
url45 = 'https://i.pinimg.com/474x/1d/05/2b/1d052b569b0a6aa895ab6e69970e4a1f.jpg'
url46 = 'https://i.pinimg.com/474x/1d/46/88/1d46880a32b27575c209bdbe71a973f0.jpg'
url47 = 'https://i.pinimg.com/474x/1a/9c/14/1a9c14c15a53abb674da066b8df907de.jpg'
url48 = 'https://i.pinimg.com/474x/1b/4c/eb/1b4cebacf74a6a9d8939bcd563759ad7.jpg'
url49 = 'https://i.pinimg.com/474x/1b/9f/3b/1b9f3b3bb949d59d19a8080a99551fb8.jpg'
url50 = 'https://i.pinimg.com/474x/1b/04/df/1b04df5a49092aa856a7c24f3bedc2af.jpg'
url51 = 'https://i.pinimg.com/474x/4f/46/24/4f4624db688e36cd07e7eeadc4f1d47e.jpg'
url52 = 'https://i.pinimg.com/474x/18/b5/6f/18b56f6f0d5a706d3a5743c2a6d3b790.jpg'
url53 = 'https://i.pinimg.com/474x/19/ce/63/19ce63f91d6e7a8616ff0b0af2aea053.jpg'
url54 = 'https://i.pinimg.com/474x/16/15/7b/16157becaeabf8fc2859f224563a6c7f.jpg'
url55 = 'https://i.pinimg.com/474x/14/6f/5a/146f5a138f612e1da98d15e77dc1cf94.jpg'
url56 = 'https://i.pinimg.com/474x/16/6f/45/166f457de12990c9300894f7eaf6052e.jpg'
url57 = 'https://i.pinimg.com/474x/16/6b/83/166b83a4ad1437d9bf63b9a93433d0dd.jpg'
url58 = 'https://i.pinimg.com/474x/14/07/f2/1407f279ea1842fc5780372aeaff53b5.jpg'
url59 = 'https://i.pinimg.com/474x/14/07/f2/1407f279ea1842fc5780372aeaff53b5.jpg'
url60 = 'https://i.pinimg.com/474x/15/3c/b4/153cb412203426acafaa7dd6ac19541b.jpg'
url61 = 'https://i.pinimg.com/474x/15/b0/04/15b0044ecc8dc4eab7f86927b1717d06.jpg'
url62 = 'https://i.pinimg.com/474x/12/6a/37/126a37deb74f3c46c06dcf1ecad2c1be.jpg'
url63 = 'https://i.pinimg.com/474x/11/e6/93/11e6931fe45fc61a7538be3c0617b009.jpg'
url64 = 'https://i.pinimg.com/474x/13/f9/80/13f9808cd553816c341f9525ec8030b6.jpg'
url65 = 'https://i.pinimg.com/474x/12/99/23/1299231087eca422ef7970a461906921.jpg'
url66 = 'https://i.pinimg.com/474x/10/14/e6/1014e6a53d2995cf8eb06ab3bb86a30b.jpg'
url67 = 'https://i.pinimg.com/474x/21/3f/0d/213f0dcd045b860b6243b344f3058702.jpg'
url68 = 'https://i.pinimg.com/474x/0e/de/1e/0ede1e3f24838d213c59d92018f9b6dc.jpg'
url69 = 'https://i.pinimg.com/474x/0f/5c/d3/0f5cd34d0314ab8d7de96a602d4b3a58.jpg'
url70 = 'https://i.pinimg.com/474x/11/c3/cb/11c3cbfd62228d1c70d4fb3895676365.jpg'
url71 = 'https://i.pinimg.com/474x/11/c3/cb/11c3cbfd62228d1c70d4fb3895676365.jpg'
url72 = 'https://i.pinimg.com/474x/0d/be/3e/0dbe3ec02c7a82b9bcb054ae292b14ca.jpg'
url73 = 'https://i.pinimg.com/474x/0c/da/b5/0cdab5591771d06b774ee41bf6accbb6.jpg'
url74 = 'https://i.pinimg.com/474x/0e/94/10/0e94107981ec9a0dc3eed14e03438c68.jpg'
url75 = 'https://i.pinimg.com/474x/0d/cc/86/0dcc8611187a3093a8fb88b6ce51225a.jpg'

data = {"url": [], "image": []}
my_db = pd.DataFrame(data=data)

for i in range(1, 76):
    url_var_name = f"url{i}"
    url = globals().get(url_var_name) 
    
    if url:
        try:
            response = requests.get(url)
            response.raise_for_status() 
            img = Image.open(BytesIO(response.content))

            new_data = {"url": [url], "image": [img]}
            new_df = pd.DataFrame(new_data)
            my_db = pd.concat([my_db, new_df], ignore_index=True)

        except Exception as e:
            print(f"Failed to load image from {url}: {e}")

my_db
# Out:
#                                                   url  \
# 0   https://i.pinimg.com/474x/3b/1c/ec/3b1cec8e035...
# 1   https://i.pinimg.com/474x/3a/04/15/3a0415feca8...
# 2   https://i.pinimg.com/474x/38/74/95/387495d3b7e...
# 3   https://i.pinimg.com/474x/38/6d/77/386d77debb7...
# 4   https://i.pinimg.com/474x/34/54/ff/3454ff98c63...
# ..                                                ...
# 70  https://i.pinimg.com/474x/11/c3/cb/11c3cbfd622...
# 71  https://i.pinimg.com/474x/0d/be/3e/0dbe3ec02c7...
# 72  https://i.pinimg.com/474x/0c/da/b5/0cdab559177...
# 73  https://i.pinimg.com/474x/0e/94/10/0e94107981e...
# 74  https://i.pinimg.com/474x/0d/cc/86/0dcc8611187...
#
#                                                 image
# 0   <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1   <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 2   <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 3   <PIL.JpegImagePlugin.JpegImageFile image mode=...
# ...

# %%
url_list = [f"url{i}" for i in range(1, 76)]
url_list
# Out:
# ['url1',
#  'url2',
#  'url3',
#  'url4',
#  'url5',
#  'url6',
#  'url7',
#  'url8',
#  'url9',
#  'url10',
#  'url11',
#  'url12',
#  'url13',
#  'url14',
#  'url15',
#  'url16',
#  'url17',
#  'url18',
#  'url19',
#  'url20',
#  'url21',
#  'url22',
#  'url23',
#  'url24',
#  'url25',
#  'url26',
#  'url27',
#  'url28',
#  'url29',
#  'url30',
#  'url31',
#  'url32',
#  'url33',
#  'url34',
#  'url35',
#  'url36',
#  'url37',
#  'url38',
#  'url39',
#  'url40',
#  'url41',
#  'url42',
#  'url43',
#  'url44',
#  'url45',
#  'url46',
#  'url47',
#  'url48',
#  'url49',
#  'url50',
#  'url51',
#  'url52',
#  'url53',
#  'url54',
#  'url55',
#  'url56',
#  'url57',
#  'url58',
#  'url59',
#  'url60',
#  'url61',
#  'url62',
#  'url63',
#  'url64',
#  'url65',
#  'url66',
#  'url67',
#  'url68',
#  'url69',
#  'url70',
#  'url71',
#  'url72',
#  'url73',
#  'url74',
#  'url75']

# %%
import numpy as np

all_pixels = []

Y_black_threshold = 0.1 
Y_white_threshold = 0.9 
UV_neutral_threshold = 0.05  

for index, row in my_db.iterrows():
    try:
        img = row["image"]
        img_yuv = img.convert("YCbCr")  
        yuv_data = np.array(img_yuv)   
        y = yuv_data[:, :, 0] 
        u = yuv_data[:, :, 1] 
        v = yuv_data[:, :, 2] 

        yuv_flat = np.column_stack([y.flatten(), u.flatten(), v.flatten()])

       
        is_black = yuv_flat[:, 0] < Y_black_threshold
        is_white = (yuv_flat[:, 0] > Y_white_threshold) & \
                   (np.abs(yuv_flat[:, 1]) < UV_neutral_threshold) & \
                   (np.abs(yuv_flat[:, 2]) < UV_neutral_threshold)
        valid_pixels = ~(is_black | is_white)

        all_pixels.append(yuv_flat[valid_pixels])
    except Exception as e:
        print(f"Failed to process image at {row['url']}: {e}")

if all_pixels:
    all_pixels_array = np.vstack(all_pixels)

    overall_avg_color = np.mean(all_pixels_array, axis=0)
    overall_std_dev = np.std(all_pixels_array, axis=0)

    print("Overall Average Color (YUV):", overall_avg_color)
    print("Overall Standard Deviation (YUV):", overall_std_dev)
else:
    print("No valid image data was found.")


#Use https://convertingcolors.com/yuv-color-71.2000_10.9500_14.4000.html?search=YUV(71.2,%2010.95,%2014.4) to interpret result
# Out:
# Overall Average Color (YUV): [120.88702644 117.69073225 141.57376504]
# Overall Standard Deviation (YUV): [71.26190717 10.95049104 14.40878335]

# %%
import numpy as np
import pandas as pd
from PIL import Image


Y_black_threshold = 0.1
Y_white_threshold = 0.9
UV_neutral_threshold = 0.05
resizing = (100, 100)

my_db["YUV_values"] = None

for index, row in my_db.iterrows():
    try:
        img = row["image"]
        img_resized = img.resize(resizing)
        img_yuv = img.convert("YCbCr")
        yuv_data = np.array(img_yuv)

        y = yuv_data[:, :, 0]
        u = yuv_data[:, :, 1]
        v = yuv_data[:, :, 2]

        yuv_flat = np.column_stack([y.flatten(), u.flatten(), v.flatten()])

        is_black = yuv_flat[:, 0] < Y_black_threshold
        is_white = (yuv_flat[:, 0] > Y_white_threshold) & \
                   (np.abs(yuv_flat[:, 1]) < UV_neutral_threshold) & \
                   (np.abs(yuv_flat[:, 2]) < UV_neutral_threshold)

        valid_pixels = ~(is_black | is_white)

        if valid_pixels.any():
            y_mean = yuv_flat[valid_pixels, 0].mean()
            u_mean = yuv_flat[valid_pixels, 1].mean()
            v_mean = yuv_flat[valid_pixels, 2].mean()
            yuv_value = (y_mean, u_mean, v_mean)
        else:
            yuv_value = (None, None, None)

        my_db.at[index, "YUV_values"] = yuv_value
    except Exception as e:
        print(f"Error processing image at index {index}: {e}")

print(my_db)
my_db.to_csv('cooltonee.csv', index=False)
# Out:
#                                                   url  \
# 0   https://i.pinimg.com/474x/3b/1c/ec/3b1cec8e035...
# 1   https://i.pinimg.com/474x/3a/04/15/3a0415feca8...
# 2   https://i.pinimg.com/474x/38/74/95/387495d3b7e...
# 3   https://i.pinimg.com/474x/38/6d/77/386d77debb7...
# 4   https://i.pinimg.com/474x/34/54/ff/3454ff98c63...
# ..                                                ...
# 70  https://i.pinimg.com/474x/11/c3/cb/11c3cbfd622...
# 71  https://i.pinimg.com/474x/0d/be/3e/0dbe3ec02c7...
# 72  https://i.pinimg.com/474x/0c/da/b5/0cdab559177...
# 73  https://i.pinimg.com/474x/0e/94/10/0e94107981e...
# 74  https://i.pinimg.com/474x/0d/cc/86/0dcc8611187...
#
#                                                 image  \
# 0   <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1   <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 2   <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 3   <PIL.JpegImagePlugin.JpegImageFile image mode=...
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

a = []

Y_black_threshold = 0.1
Y_white_threshold = 0.9
UV_neutral_threshold = 0.05
resizing = (100, 100)

for index, row in my_db.iterrows():
    try:
        img = row["image"]
        img_resized = img.resize(resizing)
        img_yuv = img.convert("YCbCr")
        yuv_data = np.array(img_yuv)

        y = yuv_data[:, :, 0]
        u = yuv_data[:, :, 1]
        v = yuv_data[:, :, 2]

        yuv_flat = np.column_stack([y.flatten(), u.flatten(), v.flatten()])

        is_black = yuv_flat[:, 0] < Y_black_threshold
        is_white = (yuv_flat[:, 0] > Y_white_threshold) & \
                   (np.abs(yuv_flat[:, 1]) < UV_neutral_threshold) & \
                   (np.abs(yuv_flat[:, 2]) < UV_neutral_threshold)

        valid_pixels = ~(is_black | is_white )

        a.append(yuv_flat[valid_pixels])
    except Exception as e:
        print(f"")

if a:
    ar = np.vstack(a)

    yuv_palette = {}
    for i, channel in enumerate(['Y', 'U', 'V']):
        channel_data = ar[:, i]
        q1 = np.percentile(channel_data, 25)
        q2 = np.median(channel_data)
        q3 = np.percentile(channel_data, 75)
        min_val = channel_data.min()
        max_val = channel_data.max()

        iqr = q3 - q1
        lower_bound = q1 - 1.5 * iqr
        upper_bound = q3 + 1.5 * iqr
        outliers = channel_data[(channel_data < lower_bound) | (channel_data > upper_bound)]

        yuv_palette[channel] = {
            "min": min_val,
            "Q1": q1,
            "median": q2,
            "Q3": q3,
            "max": max_val,
            "outliers": outliers
        }

    for channel, stats in yuv_palette.items():
        print(f"{channel} Channel:")
        print(f"  Min: {stats['min']}")
        print(f"  Q1: {stats['Q1']}")
        print(f"  Median: {stats['median']}")
        print(f"  Q3: {stats['Q3']}")
        print(f"  Max: {stats['max']}")
        print(f"  Outliers: {stats['outliers'][:10]}...")

    plt.boxplot([ar[:, 0], ar[:, 1], ar[:, 2]],
            labels=['Y', 'U', 'V'], 
            patch_artist=True,
            medianprops=dict(color='white', linewidth=2))
    plt.title("YUV Color Distribution-- Cool Tone")
    plt.ylabel("Normalized Value")
    plt.grid(True)
    plt.show()

    # Separate Histograms
    colors = ['gold', 'blue', 'red']
    for i, (channel, color) in enumerate(zip(['Y', 'U', 'V'], colors)):
        plt.figure(figsize=(8, 6))
        plt.hist(ar[:, i], bins=30, color=color, alpha=0.7, edgecolor='black')
        plt.title(f'{channel} Channel Histogram')
        plt.xlabel('Value')
        plt.ylabel('Frequency')
        plt.grid(True)
        plt.show()

else:
    print("No valid image data was found.")
# Out:
# Y Channel:
#   Min: 1
#   Q1: 58.0
#   Median: 116.0
#   Q3: 180.0
#   Max: 255
#   Outliers: []...
# U Channel:
#   Min: 6
#   Q1: 110.0
#   Median: 119.0
#   Q3: 126.0
#   Max: 190
#   Outliers: [85 85 85 85 85 85 85 85 85 85]...
# V Channel:
#   Min: 78
#   Q1: 130.0
#   Median: 138.0
#   Q3: 152.0
#   Max: 240
#   Outliers: [95 95 95 95 93 93 94 96 95 93]...
# C:\Users\Ashley Rommel\AppData\Local\Temp\ipykernel_22868\3242473354.py:70: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([ar[:, 0], ar[:, 1], ar[:, 2]],

# %%
my_db
# Out:
#                                                   url  \
# 0   https://i.pinimg.com/474x/3b/1c/ec/3b1cec8e035...
# 1   https://i.pinimg.com/474x/3a/04/15/3a0415feca8...
# 2   https://i.pinimg.com/474x/38/74/95/387495d3b7e...
# 3   https://i.pinimg.com/474x/38/6d/77/386d77debb7...
# 4   https://i.pinimg.com/474x/34/54/ff/3454ff98c63...
# ..                                                ...
# 70  https://i.pinimg.com/474x/11/c3/cb/11c3cbfd622...
# 71  https://i.pinimg.com/474x/0d/be/3e/0dbe3ec02c7...
# 72  https://i.pinimg.com/474x/0c/da/b5/0cdab559177...
# 73  https://i.pinimg.com/474x/0e/94/10/0e94107981e...
# 74  https://i.pinimg.com/474x/0d/cc/86/0dcc8611187...
#
#                                                 image  \
# 0   <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1   <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 2   <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 3   <PIL.JpegImagePlugin.JpegImageFile image mode=...
# ...
